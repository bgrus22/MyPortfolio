# %% [markdown]
# ### Setup

# %%
import pandas as pd
import numpy as np
import datetime as dt

# %%
wbdta = pd.read_excel('Data/World_Development_Indicators.xlsx', sheet_name='Data')
LCOEdta = pd.read_csv('Data/LCOE All - IEA.csv')
CoGdta = pd.read_excel('Data/levelized-capital-costs-of-electricity-generation-in-the-us-2027.xlsx', sheet_name='Data')
plants1 = pd.read_csv('Data/global_power_plant_database.csv')
matprice = pd.read_excel('Data/Primary_Commodity_Price.xlsx', sheet_name='Data')
matuse = pd.read_csv('Data/minerals-used-in-clean-energy.csv')
# Out:
# c:\Users\agrus\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# ### World Bank stuff

# %%
# get the list of columns that contain year values
year_cols = wbdta.columns[4:].tolist()

# create an empty list to store the pivoted dataframes
dfs_list = []

# loop over the unique values of Series Name
for series_name in wbdta['Series Name'].unique():
    
    # subset the dataframe for the current series
    holder = wbdta.loc[wbdta['Series Name']==series_name, ['Country Name', 'Country Code'] + year_cols]
    
    # pivot the dataframe to the desired format
    holder_pivot = holder.melt(id_vars = ['Country Name','Country Code'], var_name = 'Year', value_name = series_name)

    # set the name of the new dataframe
    holder_pivot.columns.name = None

    if series_name == "Energy intensity level of primary energy (MJ/$2017 PPP GDP)":
        dfs_list.append(holder_pivot['Country Name'])
        dfs_list.append(holder_pivot['Country Code'])
        dfs_list.append(holder_pivot['Year'])
        dfs_list.append(holder_pivot[series_name])
    else:
        dfs_list.append(holder_pivot[series_name])


# merge all dataframes into a single dataframe
merged_df = pd.concat(dfs_list, axis=1)

# %%
hold_bin = []
yval = []
#reformat the year values
for x in merged_df['Year']:
    holder = x.split(' ')
    yval.append(int(holder[0]))
    #change the year to datetime
    holder = pd.to_datetime(holder[0], format='%Y')

    hold_bin.append(holder)

merged_df['Yearint'] = yval
merged_df['Year'] = hold_bin


#fix na system
merged_df.replace('..', np.nan, inplace=True)


merged_df.head()
# Out:
#   Country Name Country Code       Year  \
# 0  Afghanistan          AFG 1971-01-01
# 1      Albania          ALB 1971-01-01
# 2      Algeria          DZA 1971-01-01
# 3       Angola          AGO 1971-01-01
# 4    Argentina          ARG 1971-01-01
#
#    Energy intensity level of primary energy (MJ/$2017 PPP GDP)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Access to electricity, rural (% of rural population)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Access to electricity, urban (% of urban population)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Access to electricity (% of population)  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#    Electricity production from coal sources (% of total)  \
# 0                                                NaN
# 1                                           0.000000
# 2                                           0.000000
# 3                                           0.000000
# 4                                           3.085845
#
#    Electricity production from oil, gas and coal sources (% of total)  \
# 0                                                NaN
# 1                                          42.857143
# 2                                          85.195155
# 3                                          18.463612
# 4                                          93.222994
#
#    Electricity production from hydroelectric sources (% of total)  ...  \
# 0                                                NaN               ...
# 1                                          57.142857               ...
# 2                                          14.804845               ...
# 3                                          81.536388               ...
# 4                                           6.535726               ...
#
#    Electric power consumption (kWh per capita)  \
# 0                                          NaN
# 1                                   532.028432
# 2                                   141.102889
# 3                                    90.010618
# 4                                   875.765516
#
#    Energy use (kg of oil equivalent per capita)  \
# 0                                           NaN
# 1                                    785.161526
# 2                                    245.527602
# 3                                    623.396059
# 4                                   1389.076933
#
#    Value lost due to electrical outages (% of sales for affected firms)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Adjusted savings: energy depletion (% of GNI)  Oil rents (% of GDP)  \
# 0                                       0.011334              0.029425
# 1                                            NaN                   NaN
# 2                                       5.179009              8.051916
# 3                                            NaN                   NaN
# 4                                       0.306210              0.394583
#
#    Fuel imports (% of merchandise imports)  \
# 0                                 5.000146
# 1                                      NaN
# 2                                 3.487314
# 3                                 3.008041
# 4                                 6.682968
#
#    Fuel exports (% of merchandise exports)  Natural gas rents (% of GDP)  \
# 0                                14.553298                      0.000000
# 1                                      NaN                           NaN
# 2                                74.852037                      0.015897
# 3                                19.947138                           NaN
# 4                                 0.488016                      0.021561
#
#    Coal rents (% of GDP)  Yearint
# 0                    NaN     1971
# 1                    NaN     1971
# 2               0.002527     1971
# 3                    NaN     1971
# 4               0.000000     1971
#
# [5 rows x 35 columns]

# %%
#drop worthless stuff
droplist = ['Oil rents (% of GDP)','Natural gas rents (% of GDP)', 'Coal rents (% of GDP)',
            'Energy intensity level of primary energy (MJ/$2017 PPP GDP)',
            'Access to electricity, rural (% of rural population)', 'Access to electricity, urban (% of urban population)',
            'Access to electricity (% of population)', 'Value lost due to electrical outages (% of sales for affected firms)',
            'Fuel exports (% of merchandise exports)'
            ]

merged_df = merged_df.drop(droplist, axis=1)
merged_df.shape
# Out:
# (7800, 26)

# %%
aggtable = merged_df[merged_df['Yearint'].astype(int) > 2018]

merged_df = merged_df.drop('Yearint', axis=1)
aggtable = aggtable.drop('Yearint', axis=1)

aggtable = aggtable.groupby('Country Name').mean().reset_index()

# %%
# save the dataframe to a CSV file
merged_df.to_csv('Final/CleanData/WB_clean.csv', index=False)

# %% [markdown]
# ### LCOE

# %%
print(LCOEdta.shape)
LCOEdta.head(3)
# Out:
# (237, 17)
#               Country Plant category         Plant type  \
# 0               Japan        Nuclear     ALWR (1152 MW)
# 1  Korea, Republic of        Nuclear     ALWR (1377 MW)
# 2               Italy        Biomass  Biomass (0.42 MW)
#
#    Construction costs (USD/MWh)  Refurbishment costs (USD/MWh)  \
# 0                         46.87                            0.0
# 1                         25.51                            0.0
# 2                         70.23                            0.0
#
#    Decommissioning costs (USD/MWh)  Total capital costs (USD/MWh)  \
# 0                             0.05                          46.92
# 1                             0.03                          25.54
# 2                             0.19                          70.42
#
#    Operations & maintenance costs (USD/MWh)  Fuel costs (th) (USD/MWh)  \
# 0                                     25.84                       0.00
# 1                                     18.44                       0.00
# 2                                     59.00                      15.62
#
#    Fuel costs (el) (USD/MWh)  Carbon price (USD/ton)  Carbon costs (USD/MWh)  \
# 0                      13.92                      30                     0.0
# 1                       9.33                      30                     0.0
# 2                     159.42                      30                     0.0
#
#    Heat price (USD/MWh)  CHP heat revenues (USD/MWh)  Discount rate  \
# 0                 37.06                          0.0           0.07
# 1                 37.06                          0.0           0.07
# 2                 37.06                          0.0           0.07
#
#    LCOE (USD/MWh) Energy type
# 0           86.67     Nuclear
# 1           53.30     Nuclear
# 2          288.84     Biomass

# %%
LCOEdta.columns
#th = thermal. el = electrical
# Out:
# Index(['Country', 'Plant category', 'Plant type',
#        'Construction costs (USD/MWh)', 'Refurbishment costs (USD/MWh)',
#        'Decommissioning costs (USD/MWh)', 'Total capital costs (USD/MWh)',
#        'Operations & maintenance costs (USD/MWh)', 'Fuel costs (th) (USD/MWh)',
#        'Fuel costs (el) (USD/MWh)', 'Carbon price (USD/ton)',
#        'Carbon costs (USD/MWh)', 'Heat price (USD/MWh)',
#        'CHP heat revenues (USD/MWh)', 'Discount rate', 'LCOE (USD/MWh)',
#        'Energy type'],
#       dtype='object')

# %%
#combine fuel cost
LCOEdta['Total Fuel cost (USD/MWh)'] = LCOEdta['Fuel costs (el) (USD/MWh)'] + LCOEdta['Fuel costs (th) (USD/MWh)']

droplist2 = ['CHP heat revenues (USD/MWh)','Discount rate','Fuel costs (el) (USD/MWh)',
             'LCOE (USD/MWh)','Carbon costs (USD/MWh)','Fuel costs (th) (USD/MWh)',
             'Heat price (USD/MWh)','Carbon price (USD/ton)',
             ]

#drop useless stuff
LCOEdta = LCOEdta.drop(droplist2, axis=1)

print(LCOEdta.shape)
LCOEdta.head(3)
# Out:
# (237, 10)
#               Country Plant category         Plant type  \
# 0               Japan        Nuclear     ALWR (1152 MW)
# 1  Korea, Republic of        Nuclear     ALWR (1377 MW)
# 2               Italy        Biomass  Biomass (0.42 MW)
#
#    Construction costs (USD/MWh)  Refurbishment costs (USD/MWh)  \
# 0                         46.87                            0.0
# 1                         25.51                            0.0
# 2                         70.23                            0.0
#
#    Decommissioning costs (USD/MWh)  Total capital costs (USD/MWh)  \
# 0                             0.05                          46.92
# 1                             0.03                          25.54
# 2                             0.19                          70.42
#
#    Operations & maintenance costs (USD/MWh) Energy type  \
# 0                                     25.84     Nuclear
# 1                                     18.44     Nuclear
# 2                                     59.00     Biomass
#
#    Total Fuel cost (USD/MWh)
# 0                      13.92
# 1                       9.33
# 2                     175.04

# %%
holdr = []
for n in LCOEdta['Plant type']:
    n = n.split(' (')
    n = n[0]
    holdr.append(n)

LCOEdta['energy_type'] = holdr

# %%
aggtable = pd.merge(LCOEdta,aggtable,left_on='Country', right_on='Country Name',how='left')
aggtable.drop('Country Name', axis=1)
aggtable.head()
# Out:
#               Country Plant category         Plant type  \
# 0               Japan        Nuclear     ALWR (1152 MW)
# 1  Korea, Republic of        Nuclear     ALWR (1377 MW)
# 2               Italy        Biomass  Biomass (0.42 MW)
# 3               Italy        Biomass  Biomass (0.45 MW)
# 4              Brazil        Biomass  Biomass (25.0 MW)
#
#    Construction costs (USD/MWh)  Refurbishment costs (USD/MWh)  \
# 0                         46.87                            0.0
# 1                         25.51                            0.0
# 2                         70.23                            0.0
# 3                         48.93                            0.0
# 4                         34.68                            0.0
#
#    Decommissioning costs (USD/MWh)  Total capital costs (USD/MWh)  \
# 0                             0.05                          46.92
# 1                             0.03                          25.54
# 2                             0.19                          70.42
# 3                             0.13                          49.07
# 4                             0.09                          34.78
#
#    Operations & maintenance costs (USD/MWh) Energy type  \
# 0                                     25.84     Nuclear
# 1                                     18.44     Nuclear
# 2                                     59.00     Biomass
# 3                                     26.89     Biomass
# 4                                     18.75     Biomass
#
#    Total Fuel cost (USD/MWh)  ...  \
# 0                      13.92  ...
# 1                       9.33  ...
# 2                     175.04  ...
# 3                       0.00  ...
# 4                       0.00  ...
#
#   GDP per unit of energy use (constant 2017 PPP $ per kg of oil equivalent)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Energy imports, net (% of energy use)  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#    Alternative and nuclear energy (% of total energy use)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Fossil fuel energy consumption (% of total)  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    Energy use (kg of oil equivalent) per $1,000 GDP (constant 2017 PPP)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Combustible renewables and waste (% of total energy)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Electric power consumption (kWh per capita)  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    Energy use (kg of oil equivalent per capita)  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#    Adjusted savings: energy depletion (% of GNI)  \
# 0                                       0.003992
# 1                                       0.001910
# 2                                       0.054715
# 3                                       0.054715
# 4                                       1.632956
#
#    Fuel imports (% of merchandise imports)
# 0                                19.091167
# 1                                21.908541
# 2                                10.429541
# 3                                10.429541
# 4                                11.979674
#
# [5 rows x 34 columns]

# %%
# save the dataframe to a CSV file
#aggtable.to_csv('Final/CleanData/LCOE.csv', index=False)
LCOEdta.to_csv('Final/CleanData/LCOE.csv', index=False)

# %% [markdown]
# ### Statista

# %%
print(CoGdta.shape)
CoGdta.head()
# Out:
# (12, 2)
#               Energy Source  Levelized Cost of Generation($ per megawatt hour)
# 0             Offshore wind                                             103.77
# 1           Battery storage                                              64.03
# 2          Advanced nuclear                                              60.71
# 3        Combustion turbine                                              53.78
# 4  Ultra-supercritical coal                                              52.11

# %%
CoGdta['Energy Source']
# Out:
# 0                Offshore wind
# 1              Battery storage
# 2             Advanced nuclear
# 3           Combustion turbine
# 4     Ultra-supercritical coal
# 5                        Hydro
# 6                      Biomass
# 7               Solar (hybrid)
# 8                 Onshore wind
# 9           Solar (standalone)
# 10                  Geothermal
# 11              Combined cycle
# Name: Energy Source, dtype: object

# %%
# save the dataframe to a CSV file
CoGdta.to_csv('Final/CleanData/capital-costs-of-electricity.csv', index=False)

# %% [markdown]
# ### Class Dataset

# %%
print(plants1.shape)
plants1.head(3)
# Out:
# (34936, 36)
#   country country_long                                          name  \
# 0     AFG  Afghanistan  Kajaki Hydroelectric Power Plant Afghanistan
# 1     AFG  Afghanistan                                  Kandahar DOG
# 2     AFG  Afghanistan                                  Kandahar JOL
#
#       gppd_idnr  capacity_mw  latitude  longitude primary_fuel other_fuel1  \
# 0  GEODB0040538         33.0    32.322     65.119        Hydro         NaN
# 1    WKS0070144         10.0    31.670     65.795        Solar         NaN
# 2    WKS0071196         10.0    31.623     65.792        Solar         NaN
#
#   other_fuel2  ... estimated_generation_gwh_2013  \
# 0         NaN  ...                        123.77
# 1         NaN  ...                         18.43
# 2         NaN  ...                         18.64
#
#    estimated_generation_gwh_2014 estimated_generation_gwh_2015  \
# 0                         162.90                         97.39
# 1                          17.48                         18.25
# 2                          17.58                         19.10
#
#   estimated_generation_gwh_2016 estimated_generation_gwh_2017  \
# 0                        137.76                        119.50
# 1                         17.70                         18.29
# 2                         17.62                         18.72
#
#   estimated_generation_note_2013 estimated_generation_note_2014  \
# 0                       HYDRO-V1                       HYDRO-V1
# 1                SOLAR-V1-NO-AGE                SOLAR-V1-NO-AGE
# 2                SOLAR-V1-NO-AGE                SOLAR-V1-NO-AGE
#
#    estimated_generation_note_2015  estimated_generation_note_2016  \
# 0                        HYDRO-V1                        HYDRO-V1
# 1                 SOLAR-V1-NO-AGE                 SOLAR-V1-NO-AGE
# 2                 SOLAR-V1-NO-AGE                 SOLAR-V1-NO-AGE
#
#    estimated_generation_note_2017
# 0                        HYDRO-V1
# 1                 SOLAR-V1-NO-AGE
# 2                 SOLAR-V1-NO-AGE
#
# [3 rows x 36 columns]

# %%
plants1.columns
# Out:
# Index(['country', 'country_long', 'name', 'gppd_idnr', 'capacity_mw',
#        'latitude', 'longitude', 'primary_fuel', 'other_fuel1', 'other_fuel2',
#        'other_fuel3', 'commissioning_year', 'owner', 'source', 'url',
#        'geolocation_source', 'wepp_id', 'year_of_capacity_data',
#        'generation_gwh_2013', 'generation_gwh_2014', 'generation_gwh_2015',
#        'generation_gwh_2016', 'generation_gwh_2017', 'generation_gwh_2018',
#        'generation_gwh_2019', 'generation_data_source',
#        'estimated_generation_gwh_2013', 'estimated_generation_gwh_2014',
#        'estimated_generation_gwh_2015', 'estimated_generation_gwh_2016',
#        'estimated_generation_gwh_2017', 'estimated_generation_note_2013',
#        'estimated_generation_note_2014', 'estimated_generation_note_2015',
#        'estimated_generation_note_2016', 'estimated_generation_note_2017'],
#       dtype='object')

# %%
droplist3 = ['estimated_generation_note_2013', 'estimated_generation_note_2014',
	'estimated_generation_note_2015', 'estimated_generation_note_2016',
    'estimated_generation_note_2017','other_fuel1',
    'other_fuel2','other_fuel3', 'commissioning_year', 'gppd_idnr','owner',
    'source', 'url', 'geolocation_source', 'wepp_id', 'year_of_capacity_data',
    'generation_data_source','generation_gwh_2013', 'generation_gwh_2014', 
    'generation_gwh_2015', 'generation_gwh_2016', 'generation_gwh_2017', 
    'generation_gwh_2018', 'generation_gwh_2019','name']

plants1 = plants1.drop(droplist3, axis=1)
plants1.head(3)
# Out:
#   country country_long  capacity_mw  latitude  longitude primary_fuel  \
# 0     AFG  Afghanistan         33.0    32.322     65.119        Hydro
# 1     AFG  Afghanistan         10.0    31.670     65.795        Solar
# 2     AFG  Afghanistan         10.0    31.623     65.792        Solar
#
#    estimated_generation_gwh_2013  estimated_generation_gwh_2014  \
# 0                         123.77                         162.90
# 1                          18.43                          17.48
# 2                          18.64                          17.58
#
#    estimated_generation_gwh_2015  estimated_generation_gwh_2016  \
# 0                          97.39                         137.76
# 1                          18.25                          17.70
# 2                          19.10                          17.62
#
#    estimated_generation_gwh_2017
# 0                         119.50
# 1                          18.29
# 2                          18.72

# %%
plants1['primary_fuel'].unique()
# Out:
# array(['Hydro', 'Solar', 'Gas', 'Other', 'Oil', 'Wind', 'Nuclear', 'Coal',
#        'Waste', 'Biomass', 'Wave and Tidal', 'Petcoke', 'Geothermal',
#        'Storage', 'CHP'], dtype=object)

# %%
droplist = ['Other', 'Oil', 'Waste', 'Wave and Tidal','Petcoke']

plants1 = plants1[~plants1['primary_fuel'].isin(droplist)]

# %%
plants1['primary_fuel'].unique()
# Out:
# array(['Hydro', 'Solar', 'Gas', 'Wind', 'Nuclear', 'Coal', 'Biomass',
#        'Geothermal', 'Storage', 'CHP'], dtype=object)

# %%
# save the dataframe to a CSV file
plants1.to_csv('Final/CleanData/globalplants1.csv', index=False)
#plants2.to_csv('Final/CleanData/globalplants2.csv', index=False)

# %% [markdown]
# ### IMF prices

# %%
matprice.head()
# Out:
#    Component          2013          2014          2015          2016  \
# 0   Chromium   8938.867278   8856.813487   8844.760673   8219.054096
# 1     Cobalt  27090.822506  30780.731957  28451.660699  25463.368543
# 2     Copper   7331.490765   6863.396581   5510.457113   4867.897430
# 3  Manganese   2317.528589   2236.811143   2012.081459   1776.361342
# 4     Nickel  15029.988580  16893.374548  11862.634519   9595.179081
#
#            2017          2018          2019          2020          2021  \
# 0   8925.346912  10905.248396   9412.283885   6930.035686   9096.638853
# 1  55832.170981  72911.236898  33177.632305  31444.926902  51235.518380
# 2   6169.939942   6529.798371   6010.145430   6174.557917   9317.409166
# 3   1977.000949   2378.426874   1899.755862   1713.635815   4053.592878
# 4  10409.634946  13114.063889  13913.908693  13790.426574  18467.051874
#
#            2022
# 0  10826.342759
# 1  63764.719304
# 2   8828.916814
# 3   4501.483390
# 4  25867.262713

# %%
# use melt function to reshape dataframe
matprice1 = pd.melt(matprice, id_vars=['Component'], var_name='Year', value_name='Price_per_Ton')
matprice1.head()
# Out:
#    Component  Year  Price_per_Ton
# 0   Chromium  2013    8938.867278
# 1     Cobalt  2013   27090.822506
# 2     Copper  2013    7331.490765
# 3  Manganese  2013    2317.528589
# 4     Nickel  2013   15029.988580

# %%
matprice1['Year'] = pd.to_datetime(matprice1['Year'], format='%Y')
matprice1.head()
# Out:
#    Component       Year  Price_per_Ton
# 0   Chromium 2013-01-01    8938.867278
# 1     Cobalt 2013-01-01   27090.822506
# 2     Copper 2013-01-01    7331.490765
# 3  Manganese 2013-01-01    2317.528589
# 4     Nickel 2013-01-01   15029.988580

# %%
matprice1.to_csv('Final/CleanData/Material_prices.csv', index=False)

# %% [markdown]
# ### IEA Materials

# %%
matuse.head()
# Out:
#       Plant Type  Copper   Nickel  Manganese  Cobalt  Chromium     Zinc  \
# 0  Offshore wind  8000.0   240.00     790.00    0.00     525.0  5500.00
# 1   Onshore wind  2900.0   403.50     780.00    0.00     470.0  5500.00
# 2       Solar PV  2822.1     1.30       0.00    0.00       0.0    29.99
# 3        Nuclear  1473.0  1297.40     147.69    0.00    2190.0     0.00
# 4           Coal  1150.0   721.04       4.63  201.46     307.5     0.00
#
#    Rare earths  Silicon  Others
# 0        239.0      0.0    6.00
# 1         14.0      0.0    0.00
# 2          0.0   3948.3   31.95
# 3          0.5      0.0   94.28
# 4          0.0      0.0   33.90

# %%
matuse1 = matuse.drop(['Rare earths','Others'], axis=1)

matuse1 = pd.melt(matuse1, id_vars=['Plant Type'], var_name='Component', value_name='Kg/MW of Capacity')

matuse1.head()
# Out:
#       Plant Type Component  Kg/MW of Capacity
# 0  Offshore wind    Copper             8000.0
# 1   Onshore wind    Copper             2900.0
# 2       Solar PV    Copper             2822.1
# 3        Nuclear    Copper             1473.0
# 4           Coal    Copper             1150.0

# %%
merge_comp = pd.merge(matuse1,matprice,on='Component',how='left')

merge_comp.head()
# Out:
#       Plant Type Component  Kg/MW of Capacity         2013         2014  \
# 0  Offshore wind    Copper             8000.0  7331.490765  6863.396581
# 1   Onshore wind    Copper             2900.0  7331.490765  6863.396581
# 2       Solar PV    Copper             2822.1  7331.490765  6863.396581
# 3        Nuclear    Copper             1473.0  7331.490765  6863.396581
# 4           Coal    Copper             1150.0  7331.490765  6863.396581
#
#           2015        2016         2017         2018        2019         2020  \
# 0  5510.457113  4867.89743  6169.939942  6529.798371  6010.14543  6174.557917
# 1  5510.457113  4867.89743  6169.939942  6529.798371  6010.14543  6174.557917
# 2  5510.457113  4867.89743  6169.939942  6529.798371  6010.14543  6174.557917
# 3  5510.457113  4867.89743  6169.939942  6529.798371  6010.14543  6174.557917
# 4  5510.457113  4867.89743  6169.939942  6529.798371  6010.14543  6174.557917
#
#           2021         2022
# 0  9317.409166  8828.916814
# 1  9317.409166  8828.916814
# 2  9317.409166  8828.916814
# 3  9317.409166  8828.916814
# 4  9317.409166  8828.916814

# %%
for n in range(2013,2023):
    merge_comp[f'{n}'] = merge_comp[f'{n}']/1000
    merge_comp[f'price in {n}'] = merge_comp[f'{n}'] * merge_comp['Kg/MW of Capacity']
    merge_comp = merge_comp.drop(f'{n}',axis=1)
merge_comp.head()
# Out:
#       Plant Type Component  Kg/MW of Capacity  price in 2013  price in 2014  \
# 0  Offshore wind    Copper             8000.0   58651.926120   54907.172644
# 1   Onshore wind    Copper             2900.0   21261.323218   19903.850084
# 2       Solar PV    Copper             2822.1   20690.200088   19369.191490
# 3        Nuclear    Copper             1473.0   10799.285897   10109.783163
# 4           Coal    Copper             1150.0    8431.214380    7892.906068
#
#    price in 2015  price in 2016  price in 2017  price in 2018  price in 2019  \
# 0   44083.656902   38943.179437   49359.519535   52238.386968   48081.163437
# 1   15980.325627   14116.902546   17892.825831   18936.415276   17429.421746
# 2   15551.061018   13737.693336   17412.187510   18427.743983   16961.231417
# 3    8116.903327    7170.412914    9088.321534    9618.393000    8852.944218
# 4    6337.025680    5598.082044    7095.430933    7509.268127    6911.667244
#
#    price in 2020  price in 2021  price in 2022
# 0   49396.463339   74539.273327   70631.334513
# 1   17906.217960   27020.486581   25603.858761
# 2   17425.219898   26294.660407   24916.086141
# 3    9095.123812   13724.543701   13004.994467
# 4    7100.741605   10715.020541   10153.254336

# %%
merge_comp.to_csv('Final/CleanData/Plant_Materials.csv', index=False)
